# %% [markdown]
# # Mendefinisikan Variable Penting

# %%
# Variable Penting
testSize = 0.20 #Pembagian ukuran datatesing

MAX_NB_WORDS = 100000 #Maximum jumlah kata pada vocabulary yang akan dibuat
max_seq_len = 0 #Panjang kalimat maximum

num_epochs = 300 #Jumlah perulangan / epoch saat proses training

# %% [markdown]
# # Import Module

# %%
# Import CSV
import csv
# Import json
import json
# Import Pandas
import pandas as pd
# Settingan di Pandas untuk menghilangkan warning
pd.options.mode.chained_assignment = None  # default='warn'

# Import Numpy
import numpy as np

# Loading Bar TQDM
from tqdm import tqdm
7
# Stopword Removal
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

# Stemming (Sastrawi)
# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Tokenizer
from keras.preprocessing.text import Tokenizer

# pad_sequences untuk google colab
# from keras.utils import pad_sequences
# pad_sequences untuk jupter-lab
from keras_preprocessing.sequence import pad_sequences

# Pickle FastText
import pickle

# Split Data
from sklearn.model_selection import train_test_split

# Label Encoder
from sklearn.preprocessing import LabelEncoder

# Model Building
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.layers import Dropout
from tensorflow.keras.backend import clear_session
from keras.models import load_model

# Callbacks
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# Plot Model
from keras.utils import plot_model

# Grafik
import matplotlib.pyplot as plt
import seaborn as sn
sn.set_style("whitegrid")

# Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Function Membaca file JSON menjadi DataFrame

# %%
def read_data(filename):
    # Membaca file intents.json untuk dijadikan Dataframe
    df = pd.read_csv(filename) 
    return df

# %% [markdown]
# # Memanggil Function read_data

# %%
# Memanggil Function Read Data
FileIntents = './Dataset/Intents.csv'
df = read_data(FileIntents)
df
# Out:
#                                             Pertanyaan  \
# 0    Apa perbedaan antara investasi jangka pendek d...
# 1    Bagaimana cara mengelola risiko dalam investas...
# 2    Apa yang harus diperhatikan saat memilih saham...
# 3     Bagaimana cara mengukur kinerja investasi saham?
# 4      Bagaimana cara memahami risiko investasi saham?
# ..                                                 ...
# 343                                       Apaitu Moat?
# 344                                    Apa itu broker?
# 345                                        Apa itu rdn
# 346                                   apa itu cutloss?
# 347                             apa itu trailing stop?
#
#                                                Jawaban      Label
# 0    Investasi jangka pendek biasanya berlangsung d...  Investasi
# 1    Beberapa cara untuk mengelola risiko dalam inv...  Investasi
# 2    Saat memilih saham untuk investasi perhatikan ...  Investasi
# 3    Kinerja investasi saham dapat diukur dengan me...  Investasi
# 4    Memahami risiko investasi saham melibatkan pen...  Investasi
# ..                                                 ...        ...
# 343  Moat adalah "keunggulan" yang dimiliki perusah...    Istilah
# 344  Broker adalah perantara antara pembeli dan pen...    Istilah
# 345  Rekening Dana Nasabah (RDN) adalah rekening ya...    Istilah
# 346  Cut loss (memotong kerugian) adalah tindakan m...    Istilah
# 347  trailing stop adalah fitur untuk melakukan pen...    Istilah
#
# [348 rows x 3 columns]

# %%
# Membuat fungsi label encoder
def encode_label(df):
    # Encoding Categorical Data (Mengubah data kategorikal menjadi angka)
    from sklearn.preprocessing import LabelEncoder
    LE = LabelEncoder()
    df['Label_Encoded'] = LE.fit_transform(df['Label'])
    pickle.dump(LE, open('LE.pkl','wb'))
    return df

# %%
# Menampilkan Label sebelum dan sesudah encoded
df = encode_label(df)
pd.set_option("max_rows", None)
label = df[['Label','Label_Encoded']].sort_values(["Label_Encoded"],ascending=[True]).drop_duplicates().reset_index(drop=True)
label
# Out:
#        Label  Label_Encoded
# 0        IPO              0
# 1  Investasi              1
# 2    Istilah              2
# 3   Strategi              3
# 4    Trading              4

# %%
def preprocessing(data):
    # Case Folding
    data['lower'] = data['Pertanyaan'].str.lower()
    
    # Punctual Removal
    data['punctual'] = data['lower'].str.replace('[^a-zA-Z0-9]+',' ', regex=True)
    
    # Normalization
    kamus_baku = pd.read_csv('kata_baku.csv', sep=";")
    dict_kamus_baku = kamus_baku[['slang','baku']].to_dict('list')
    dict_kamus_baku = dict(zip(dict_kamus_baku['slang'], dict_kamus_baku['baku']))
    norm = []
    for i in data['punctual']:
        res = " ".join(dict_kamus_baku.get(x, x) for x in str(i).split())
        norm.append(str(res))
    data['normalize'] = norm
    
    # Stopword Removal
    stop_words = set(stopwords.words('indonesian'))
    swr = []
    from tqdm import tqdm
    for i in tqdm(data['normalize']):
        tokens = word_tokenize(i)
        filtered = [word for word in tokens if word not in stop_words]
        swr.append(" ".join(filtered))
    data['stopwords'] = swr
    
    # Stemming
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    stem = []
    from tqdm import tqdm
    for i in tqdm(data['stopwords']):
        stem.append(stemmer.stem(str(i)))
    data['stemmed'] = stem
    
    return data

# %%
df = preprocessing(df)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 348/348 [00:00<00:00, 7249.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 348/348 [00:21<00:00, 16.16it/s]

# %%
# data splitting
df_training, df_testing = train_test_split(df, test_size=testSize, random_state=40, shuffle=True)
df_training = df_training.reset_index(drop=True)
df_testing  = df_testing.reset_index(drop=True)

# %%
# Mengecek panjang kalimat maksimum
longest_string = max(df['stemmed'].values.tolist(), key=len)
max_seq_len = len(longest_string.split())
pickle.dump(max_seq_len, open('max_seq_len.pkl','wb'))
print(longest_string)
print(max_seq_len)
# Out:
# pengaruh faktor ekonomi global pasar saham investasi saham
# 8

# %%
def tokenize_corpus(data_corpus):
    global corpus_tokenizer
    from keras.preprocessing.text import Tokenizer
    corpus_tokenizer = Tokenizer(oov_token="<OOV>")
    corpus_tokenizer.fit_on_texts(data_corpus['stemmed'])
    corpus_sequences = corpus_tokenizer.texts_to_sequences(data_corpus['stemmed'])
    corpus_word_index = corpus_tokenizer.word_index
    return corpus_sequences, corpus_word_index

def tokenize_training(data_training):
    global model_tokenizer #Menggunakan variabel global agar 'tokenizer' bisa dipake di luar fungsi ini
    from keras.preprocessing.text import Tokenizer
    model_tokenizer = Tokenizer(oov_token = "<OOV>")
    model_tokenizer.fit_on_texts(data_training['stemmed'])
    model_word_index = model_tokenizer.word_index
    train_sequences = model_tokenizer.texts_to_sequences(data_training['stemmed'])
    max_seq_len = pickle.load(open('max_seq_len.pkl', 'rb'))
    train_sequences_padded = pad_sequences(train_sequences, maxlen = max_seq_len)
    return train_sequences, train_sequences_padded, model_word_index

def tokenize_testing(data_testing):
    test_model_sequences = model_tokenizer.texts_to_sequences(data_testing['stemmed'])
    max_seq_len = pickle.load(open('max_seq_len.pkl', 'rb'))
    test_model_sequences_padded = pad_sequences(test_model_sequences, maxlen = max_seq_len)
    test_corpus_sequences = corpus_tokenizer.texts_to_sequences(data_testing['stemmed'])
    return test_model_sequences, test_model_sequences_padded, test_corpus_sequences

# %%
corpus_sequences, corpus_word_index = tokenize_corpus(df)
train_sequences, train_sequences_padded, model_word_index  = tokenize_training(df_training)
test_model_sequences, test_model_sequences_padded, test_corpus_sequences = tokenize_testing(df_testing)
print("Sebelum Tokenizer :" , df_training['stemmed'][0])
print("Setelah Tokenizer :" , train_sequences_padded[0])
# Out:
# Sebelum Tokenizer : peran analisis fundamental pilih saham investasi
# Setelah Tokenizer : [ 0  0 78  4 28 16  2  3]

# %%
# Alasan sequence model untuk predict berbentuk 2 dimensional array
# print(corpus_tokenizer.texts_to_sequences(['idx30']))
# print(corpus_tokenizer.texts_to_sequences('idx30'))

# %%
print("Model Tokenized Word :",len(list(model_word_index.keys())))
print("Corpus Tokenized Word :",len(list(corpus_word_index.keys())))
# Out:
# Model Tokenized Word : 335
# Corpus Tokenized Word : 376

# %%
# corpus_word_index

# %%
pickle.dump(model_tokenizer, open('model_tokenizer.pkl','wb'))
pickle.dump(corpus_tokenizer, open('corpus_tokenizer.pkl','wb'))
pickle.dump(corpus_word_index, open('corpus_word_index.pkl','wb'))

# %%
# pertanyaan df_training setelah di sequencing
df_training['Sequences'] = train_sequences

# %%
# Pertanyaan df_testing setelah di tokenize
df_testing = df_testing.reset_index(drop=True) #Reset Index
df_testing['Model_Sequences'] = test_model_sequences
df_testing['Corpus_Sequences'] = test_corpus_sequences

# %%
df['Sequences'] = corpus_sequences

# %%
nb_words = min(MAX_NB_WORDS, len(model_word_index)+1)

# %%
# Penentuan X (input) dan Y (output)
X_train = train_sequences_padded
X_test = test_model_sequences_padded

# One Hot Encoded Label
Y_train = pd.get_dummies(df_training['Label']).values
Y_test = pd.get_dummies(df_testing['Label']).values

# %%
model = keras.Sequential([
        keras.layers.Embedding(nb_words,100,input_length=max_seq_len),
        keras.layers.LSTM(32),# returns a sequence of vectors of dimension 32 ini
        keras.layers.Dense(len(Y_train[0]), activation='softmax')
    ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 100)            33600
#
#  lstm (LSTM)                 (None, 32)                17024
#
#  dense (Dense)               (None, 5)                 165
#
# =================================================================
# Total params: 50,789
# Trainable params: 50,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
# One Hot Label Encoded
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', patience=3)
chatbotmodel = model.fit(X_train, Y_train,
        epochs = 300, 
        callbacks = [es],
        validation_split=0.15,
        verbose = True # Verbose = 0 (tidak nampak progress), 1/True (progress bar), 2 (angka)
)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 3s 116ms/step - loss: 1.5886 - accuracy: 0.4703 - val_loss: 1.5106 - val_accuracy: 0.7857
# Epoch 2/300
# 8/8 [==============================] - 0s 11ms/step - loss: 1.4773 - accuracy: 0.6653 - val_loss: 1.3385 - val_accuracy: 0.7857
# Epoch 3/300
# 8/8 [==============================] - 0s 11ms/step - loss: 1.3006 - accuracy: 0.6653 - val_loss: 1.0131 - val_accuracy: 0.7857
# Epoch 4/300
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0333 - accuracy: 0.6653 - val_loss: 0.6802 - val_accuracy: 0.7857
# Epoch 5/300
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9886 - accuracy: 0.6653 - val_loss: 0.6203 - val_accuracy: 0.7857
# Epoch 6/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9100 - accuracy: 0.6653 - val_loss: 0.6312 - val_accuracy: 0.7857
# Epoch 7/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8596 - accuracy: 0.6737 - val_loss: 0.5927 - val_accuracy: 0.8095
# Epoch 8/300
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8095 - accuracy: 0.6864 - val_loss: 0.5217 - val_accuracy: 0.8095
# Epoch 9/300
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7608 - accuracy: 0.6992 - val_loss: 0.4508 - val_accuracy: 0.8333
# Epoch 10/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7228 - accuracy: 0.7203 - val_loss: 0.4564 - val_accuracy: 0.8810
# Epoch 11/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6646 - accuracy: 0.7754 - val_loss: 0.3924 - val_accuracy: 0.8810
# Epoch 12/300
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6259 - accuracy: 0.7797 - val_loss: 0.3490 - val_accuracy: 0.9048
# Epoch 13/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5815 - accuracy: 0.8051 - val_loss: 0.3774 - val_accuracy: 0.9524
# Epoch 14/300
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5490 - accuracy: 0.8390 - val_loss: 0.3145 - val_accuracy: 0.9524
# Epoch 15/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5061 - accuracy: 0.8347 - val_loss: 0.2947 - val_accuracy: 0.9524
# Epoch 16/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4732 - accuracy: 0.8644 - val_loss: 0.2920 - val_accuracy: 0.9524
# Epoch 17/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4344 - accuracy: 0.8856 - val_loss: 0.2617 - val_accuracy: 0.9524
# Epoch 18/300
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3992 - accuracy: 0.8983 - val_loss: 0.2446 - val_accuracy: 0.9524
# Epoch 19/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3634 - accuracy: 0.9195 - val_loss: 0.2235 - val_accuracy: 0.9524
# Epoch 20/300
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3262 - accuracy: 0.9153 - val_loss: 0.2175 - val_accuracy: 0.9524
# Epoch 21/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2986 - accuracy: 0.9280 - val_loss: 0.2056 - val_accuracy: 0.9762
# Epoch 22/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2655 - accuracy: 0.9364 - val_loss: 0.1737 - val_accuracy: 0.9762
# Epoch 23/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2436 - accuracy: 0.9407 - val_loss: 0.1895 - val_accuracy: 0.9762
# Epoch 24/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2295 - accuracy: 0.9364 - val_loss: 0.1903 - val_accuracy: 0.9524
# Epoch 25/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1986 - accuracy: 0.9619 - val_loss: 0.1492 - val_accuracy: 0.9524
# Epoch 26/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1816 - accuracy: 0.9661 - val_loss: 0.1720 - val_accuracy: 0.9286
# Epoch 27/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1661 - accuracy: 0.9661 - val_loss: 0.1889 - val_accuracy: 0.9286
# Epoch 28/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1544 - accuracy: 0.9661 - val_loss: 0.1415 - val_accuracy: 0.9524
# Epoch 29/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1395 - accuracy: 0.9788 - val_loss: 0.2242 - val_accuracy: 0.9048
# Epoch 30/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1278 - accuracy: 0.9746 - val_loss: 0.1495 - val_accuracy: 0.9286
# Epoch 31/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1236 - accuracy: 0.9746 - val_loss: 0.1862 - val_accuracy: 0.9286

# %%
plot_model(model,to_file='model.png',show_shapes=True,show_layer_names=True)

# %%
model.save('chatbotmodel.h5', chatbotmodel)

# %%
plt.figure()
plt.plot(chatbotmodel.history['loss'], lw=2.0, color='b', label='train')
plt.plot(chatbotmodel.history['val_loss'], lw=2.0, color='r', label='val')
plt.title("Loss History")
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(chatbotmodel.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(chatbotmodel.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title("Accuracy History")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
def predict_test(model,test_sequences_padded):
    categorical_predicted_label = []
    onehot_predicted_label = model.predict(test_sequences_padded)
    for i in range(0,len(test_sequences_padded)):
        categorical_predicted_label.append(onehot_predicted_label[i].argmax())
    return onehot_predicted_label, categorical_predicted_label

# %%
pd.set_option("max_rows", None)
onehot_predicted_label, df_testing['Predicted_Label'] = predict_test(model,test_model_sequences_padded)
df_testing[['Pertanyaan','Label_Encoded','Predicted_Label']].loc[df_testing['Label_Encoded'] != df_testing['Predicted_Label']]
# Out:
# 3/3 [==============================] - 1s 3ms/step
#                                            Pertanyaan  Label_Encoded  \
# 1   Bagaimana pengaruh berita dan peristiwa ekonom...              3
# 11                Bagaimana diversifikasi portofolio?              3
# 21  Apa saja itu jenis utang berdasarkan karakteri...              2
# 24  Apa yang dimaksud dengan analisis teknikal dal...              1
# 30   Bagaimana cara mengukur kinerja investasi saham?              1
# 31  Apa yang dimaksud dengan analisis fundamental ...              1
# 32  Apa yang dimaksud dengan analisis teknikal dal...              1
# 33                        EPS dikatakan baik apabila?              1
# 36                         Apa itu saham IPO lock-up?              2
# 37                 Apa arti dari kebebasan finansial?              2
# 39  Apa saja komponen laporan keuangan dalam inves...              1
# 47             Apa itu IPO (Initial Public Offering)?              2
# 50                 Untuk apa melakukan trading saham?              4
# 51  Apa yang menjadi fokus dari analisis fundament...              1
# 52                         DY dikatakan baik apabila?              1
# 53         Contoh Indeks Saham dalam investasi saham?              1
# 63                        DER dikatakan baik apabila?              1
#
#     Predicted_Label
# 1                 2
# 11                2
# 21                3
# 24                2
# 30                3
# 31                2
# 32                2
# 33                2
# 36                0
# 37                3
# 39                2
# 47                0
# 50                2
# 51                2
# 52                2
# 53                2
# 63                2

# %%
def plot_confusion_matrix(data, labels, output_filename):
    import seaborn as sn
    sn.set(color_codes=True)
    import matplotlib.pyplot as plt
    plt.figure(1, figsize=(9, 6))
    plt.title("Confusion Matrix")
    sn.set(font_scale=1.4)
    ax = sn.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
    ax.set(ylabel="Predicted Label", xlabel="True Label")
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.close()
cm = confusion_matrix(df_testing[['Predicted_Label']], df_testing[['Label_Encoded']])
plot_confusion_matrix(cm, ['IPO','Investasi','Istilah','Strategi','Trading'], 'confusion_matrix.png')

# %%
label
# Out:
#        Label  Label_Encoded
# 0        IPO              0
# 1  Investasi              1
# 2    Istilah              2
# 3   Strategi              3
# 4    Trading              4

# %%
df_testing.shape
# Out:
# (70, 12)

# %%
df_testing[['Label_Encoded','Predicted_Label']].loc[df_testing['Label_Encoded'] != df_testing['Predicted_Label']].shape
# Out:
# (17, 2)

# %%
# Pembagian dataframe_corpus berdasarkan label untuk matching
df_IPO = df[['Pertanyaan','Jawaban','Sequences']].loc[df['Label_Encoded']==int(0)].reset_index(drop=True)
df_Investasi = df[['Pertanyaan','Jawaban','Sequences']].loc[df['Label_Encoded']==int(1)].reset_index(drop=True)
df_Istilah = df[['Pertanyaan','Jawaban','Sequences']].loc[df['Label_Encoded']==int(2)].reset_index(drop=True)
df_Strategi = df[['Pertanyaan','Jawaban','Sequences']].loc[df['Label_Encoded']==int(3)].reset_index(drop=True)
df_Trading = df[['Pertanyaan','Jawaban','Sequences']].loc[df['Label_Encoded']==int(4)].reset_index(drop=True)

# %%
pickle.dump(df_IPO, open('df_IPO.pkl','wb'))
pickle.dump(df_Investasi, open('df_Investasi.pkl','wb'))
pickle.dump(df_Istilah, open('df_Istilah.pkl','wb'))
pickle.dump(df_Strategi, open('df_Strategi.pkl','wb'))
pickle.dump(df_Trading, open('df_Trading.pkl','wb'))

# %%
# Pembagian dataframe_testing berdasarkan predicted label untuk matching
def matching_testing(df_testing):
    Prediksi_Jawaban = []
    for row in range(len(df_testing)):
        #Mengambil Predicted_Label per baris
        Predicted_Label = df_testing['Predicted_Label'].iloc[row] 
        # Menentukan df yang dipakai untuk matching
        if(Predicted_Label==0):
            df_IPO = pickle.load(open('df_IPO.pkl', 'rb'))
            check_df = df_IPO
        elif(Predicted_Label==1):
            df_Investasi = pickle.load(open('df_Investasi.pkl', 'rb'))
            check_df = df_Investasi
        elif(Predicted_Label==2):
            df_Istilah = pickle.load(open('df_Istilah.pkl', 'rb'))
            check_df = df_Istilah
        elif(Predicted_Label==3):
            df_Strategi = pickle.load(open('df_Strategi.pkl', 'rb'))
            check_df = df_Strategi
        elif(Predicted_Label==4):
            df_Trading = pickle.load(open('df_Trading.pkl', 'rb'))
            check_df = df_Trading
    
        Compatibility = [0]*len(check_df)
        
        # Looping tiap baris Sequences check_df
        index = 0
        for check_sequences in check_df['Sequences']:
            # Looping tiap element Sequences df testing per baris
            for element in df_testing['Corpus_Sequences'].iloc[row]:
                if(element in check_sequences):
                    Compatibility[index]+=1
            print()
            Compatibility[index] = Compatibility[index]/len(df_testing['Corpus_Sequences'].iloc[row])
            index += 1
    
        index_max_compatibility = []
        for idx, value in enumerate(Compatibility):
            if value == max(Compatibility):
                index_max_compatibility.append(idx)

        perfect_compatibilty_sequence = []
        perfect_compatibilty_index = 0
        for idx in index_max_compatibility:
            if (idx == index_max_compatibility[0]):
                perfect_compatibilty_sequence = check_df['Sequences'].iloc[idx]
                perfect_compatibilty_index = idx
            else:
                if(len(check_df['Sequences'].iloc[idx]) <= len(perfect_compatibilty_sequence)):
                    perfect_compatibilty_sequence = check_df['Sequences'].iloc[idx]
                    perfect_compatibilty_index = idx

        Prediksi_Jawaban.append(check_df['Jawaban'].iloc[perfect_compatibilty_index])
    return Prediksi_Jawaban

# %%
Prediksi_Jawaban = matching_testing(df_testing)
df_testing['Prediksi_Jawaban'] = Prediksi_Jawaban

# %%
df_testing[['Pertanyaan','Jawaban','Prediksi_Jawaban']].loc[df_testing['Jawaban']!=df_testing['Prediksi_Jawaban']]
# Out:
#                                            Pertanyaan  \
# 1   Bagaimana pengaruh berita dan peristiwa ekonom...
# 4                                    Apa itu dividen?
# 19                            Apa itu saham preferen?
# 21  Apa saja itu jenis utang berdasarkan karakteri...
# 24  Apa yang dimaksud dengan analisis teknikal dal...
# 30   Bagaimana cara mengukur kinerja investasi saham?
# 31  Apa yang dimaksud dengan analisis fundamental ...
# 32  Apa yang dimaksud dengan analisis teknikal dal...
# 33                        EPS dikatakan baik apabila?
# 36                         Apa itu saham IPO lock-up?
# 37                 Apa arti dari kebebasan finansial?
# 39  Apa saja komponen laporan keuangan dalam inves...
# 47             Apa itu IPO (Initial Public Offering)?
# 48                  Apa yang dimaksud dengan dividen?
# 50                 Untuk apa melakukan trading saham?
# 51  Apa yang menjadi fokus dari analisis fundament...
# 52                         DY dikatakan baik apabila?
# 53         Contoh Indeks Saham dalam investasi saham?
# 55                           Apa itu saham blue chip?
# 63                        DER dikatakan baik apabila?
# 64                                      Saham adalah?
#
#                                               Jawaban  \
# 1   Berita dan peristiwa ekonomi dapat memiliki pe...
# 4   Dividen adalah pembagian sebagian dari laba pe...
# 19  Saham preferen adalah jenis saham yang memberi...
# 21  a. Interest-bearing debt, utang yang menghasil...
# 24  Analisis teknikal adalah metode analisis yang ...
# 30  Kinerja investasi saham dapat diukur dengan me...
# 31  Analisis fundamental adalah metode analisis ya...
# 32  Analisis teknikal adalah metode analisis yang ...
# 33  EPS yang meningkat menunjukkan bahwa usaha emi...
# 36  Saham IPO lock-up adalah periode waktu setelah...
# 37  Kebebasan finansial artinya memiliki kecukupan...
# 39  a. Laporan posisi keuangan atau neraca (Balanc...
# 47  IPO atau Initial Public Offering adalah istila...
# 48  Dividen adalah pembagian sebagian dari laba pe...
# 50  Tujuan trading adalah untuk mengejar keuntunga...
# 51  Analisis fundamental berfokus pada performa bi...
# 52  DY yang meningkat menunjukkan bahwa emiten sah...
# 53  Contoh indeks saham terkenal adalah S&P 500, D...
# 55  Saham blue chip adalah saham perusahaan yang t...
# 63  DER yang baik terjadi ketika nilai DER rendah,...
# 64  Saham adalah instrumen keuangan yang mewakili ...
#
#                                      Prediksi_Jawaban
# 1   Stock split adalah pembagian saham yang ada me...
# 4   Dividen adalah bagian laba perusahaan pada sua...
# 19  Saham preferen adalah jenis saham yang memberi...
# 21  Karakteristik investasi bodong adalah: a. Retu...
# 24  Analisis saham teknikal melibatkan penggunaan ...
# 30  Kinerja manajemen perusahaan dapat diukur deng...
# 31  Analisis fundamental adalah pendekatan untuk m...
# 32  Analisis saham teknikal melibatkan penggunaan ...
# 33  EPS adalah singkatan dari Earning Per Share at...
# 36  Harga saham dalam IPO ditentukan berdasarkan b...
# 37  Kebebasan finansial dapat diraih melalui dua c...
# 39  Laporan Keuangan adalah catatan informasi keun...
# 47  IPO adalah proses di mana perusahaan pertama k...
# 48  Dividen adalah bagian laba perusahaan pada sua...
# 50  Trading saham adalah transaksi jual beli surat...
# 51  Analisis fundamental adalah pendekatan untuk m...
# 52  Saham dividend yield adalah rasio yang menguku...
# 53  Indeks saham digunakan sebagai indikator untuk...
# 55  Saham blue chip adalah istilah dalam saham yan...
# 63  Debt-to-equity Ratio (DER) = Total utang berbu...
# 64  Saham adalah instrumen investasi berupa surat ...

# %%
df_testing[['Pertanyaan','Jawaban','Prediksi_Jawaban']]
# Out:
#                                            Pertanyaan  \
# 0   Bagaimana cara memilih saham yang cocok untuk ...
# 1   Bagaimana pengaruh berita dan peristiwa ekonom...
# 2                                         Apa itu BEI
# 3   Bagaimana cara memahami dan menggunakan indika...
# 4                                    Apa itu dividen?
# 5                            Apa itu Saham small cap?
# 6                              Apa itu short selling?
# 7                                     Apa itu Bearish
# 8                          Apa itu IDX Small-Mid Cap?
# 9   Apa yang dimaksud dengan Earning per Share (EP...
# 10  Bagaimana cara membaca dan memahami laporan la...
# 11                Bagaimana diversifikasi portofolio?
# 12                              Apa itu IDX Property?
# 13                      Bagaimana cara menjual saham?
# 14                                    Apa itu broker?
# 15  Bagaimana cara mengenali saham yang mengalami ...
# 16  Apa yang dimaksud dengan analisis teknikal yan...
# 17                           Apa itu saham high beta?
# 18                           Apa itu IDX Agriculture?
# 19                            Apa itu saham preferen?
# 20                               Apa itu IDX Shariah?
# 21  Apa saja itu jenis utang berdasarkan karakteri...
# 22  Bagaimana cara menggunakan analisis sentimen d...
# 23        Apa itu IHSG (Indeks Harga Saham Gabungan)?
# 24  Apa yang dimaksud dengan analisis teknikal dal...
# 25  Bagaimana cara memahami laporan keuangan perus...
# 26                       Apa itu Profitability Ratio?
# 27  Dari mana saja pendapatan bisa diperoleh untuk...
# 28                            Apa itu saham cyclical?
# 29             Apa yang dimaksud dengan indeks saham?
# 30   Bagaimana cara mengukur kinerja investasi saham?
# 31  Apa yang dimaksud dengan analisis fundamental ...
# 32  Apa yang dimaksud dengan analisis teknikal dal...
# 33                        EPS dikatakan baik apabila?
# 34  Bagaimana cara mengenali saham dengan potensi ...
# 35  Apa yang harus dipertimbangkan oleh investor s...
# 36                         Apa itu saham IPO lock-up?
# 37                 Apa arti dari kebebasan finansial?
# 38  Bagaimana membedakan saham blue chip mid cap d...
# 39  Apa saja komponen laporan keuangan dalam inves...
# 40  Apakah ada metode strategi untuk mengidentifik...
# 41                             Apa itu Swing Trading?
# 42                             Apa itu trading saham?
# 43  Bagaimana pengaruh berita dan rumor terhadap h...
# 44        Apa yang dimaksud dengan analisis sektoral?
# 45  Apa yang dimaksud dengan saham dividend yield ...
# 46                                     Apa itu Bandar
# 47             Apa itu IPO (Initial Public Offering)?
# 48                  Apa yang dimaksud dengan dividen?
# 49  Berapa jenis opini auditor yang ada dan manaka...
# 50                 Untuk apa melakukan trading saham?
# 51  Apa yang menjadi fokus dari analisis fundament...
# 52                         DY dikatakan baik apabila?
# 53         Contoh Indeks Saham dalam investasi saham?
# 54  Bagaimana cara mengukur tingkat risiko saham d...
# 55                           Apa itu saham blue chip?
# 56                   Apa itu EPS (Earning Per Share)?
# 57                                Apa itu depresiasi?
# 58                          Apa itu Dividen Properti?
# 59                        Apa itu berinvestasi saham?
# 60                Apa itu saham blue chip consortium?
# 61  Apa perbedaan antara investasi jangka pendek d...
# 62  Bagaimana cara mengidentifikasi saham overvalu...
# 63                        DER dikatakan baik apabila?
# 64                                      Saham adalah?
# 65        Apa itu lot dalam perdagangan saham di BEI?
# 66                                       Apa itu Lot?
# 67      Apa keuntungan berinvestasi dalam reksa dana?
# 68  Apa yang harus dilakukan jika terjadi kegagala...
# 69                                     Apa itu IDX80?
#
#                                               Jawaban  \
# 0   Memilih saham untuk investasi jangka panjang m...
# 1   Berita dan peristiwa ekonomi dapat memiliki pe...
# 2   Bursa Efek Indonesia merupakan lembaga yang me...
# 3   Indikator teknis adalah alat yang digunakan da...
# 4   Dividen adalah pembagian sebagian dari laba pe...
# 5   Saham small cap adalah saham lapis tiga, yaitu...
# 6   Short selling adalah strategi di mana seorang ...
# 7   Bearish adalah istilah dalam saham yang diguna...
# 8   IDX Small-Mid Cap adalah indeks saham yang men...
# 9   Earning per Share atau EPS ialah rasio dari ne...
# 10  Laporan laba rugi perusahaan memberikan gambar...
# 11  Diversifikasi portofolio adalah strategi inves...
# 12  IDX Property adalah indeks saham yang mencakup...
# 13  Langkah - langkah cara menjual saham:\n1. Logi...
# 14  Broker adalah perantara antara pembeli dan pen...
# 15  Mengenali saham yang mengalami manipulasi pasa...
# 16  Analisis teknikal yang berkelanjutan melibatka...
# 17  Saham high beta adalah saham yang cenderung me...
# 18  IDX Agriculture adalah indeks saham yang menca...
# 19  Saham preferen adalah jenis saham yang memberi...
# 20  IDX Shariah adalah indeks saham yang mencakup ...
# 21  a. Interest-bearing debt, utang yang menghasil...
# 22  Analisis sentimen melibatkan memantau dan meng...
# 23  IHSG atau Indeks Harga Saham Gabungan adalah i...
# 24  Analisis teknikal adalah metode analisis yang ...
# 25  Untuk memahami laporan keuangan perusahaan pen...
# 26  Profitability Ratio adalah rasio yang digunaka...
# 27  Pendapatan bisa diperoleh dari pekerjaan tetap...
# 28  Saham cyclical adalah saham dari perusahaan ya...
# 29  Indeks saham adalah ukuran statistik yang meng...
# 30  Kinerja investasi saham dapat diukur dengan me...
# 31  Analisis fundamental adalah metode analisis ya...
# 32  Analisis teknikal adalah metode analisis yang ...
# 33  EPS yang meningkat menunjukkan bahwa usaha emi...
# 34  Mengenali saham dengan potensi pertumbuhan yan...
# 35  Investor perlu mempertimbangkan berbagai fakto...
# 36  Saham IPO lock-up adalah periode waktu setelah...
# 37  Kebebasan finansial artinya memiliki kecukupan...
# 38  Saham blue chip mengacu pada saham perusahaan ...
# 39  a. Laporan posisi keuangan atau neraca (Balanc...
# 40  Salah satu metode yang dapat digunakan untuk m...
# 41  Swing Trading dikenal sebagai sebuah strategi ...
# 42  Trading saham adalah transaksi jual beli surat...
# 43  Berita dan rumor dapat memiliki dampak signifi...
# 44  Analisis sektoral adalah proses menganalisis k...
# 45  Saham dividend yield adalah rasio yang menguku...
# 46  Bandar merupakan istilah gaul dalam saham yang...
# 47  IPO atau Initial Public Offering adalah istila...
# 48  Dividen adalah pembagian sebagian dari laba pe...
# 49  Terdapat 5 jenis opini auditor, tapi kita waji...
# 50  Tujuan trading adalah untuk mengejar keuntunga...
# 51  Analisis fundamental berfokus pada performa bi...
# 52  DY yang meningkat menunjukkan bahwa emiten sah...
# 53  Contoh indeks saham terkenal adalah S&P 500, D...
# 54  Tingkat risiko saham dapat diukur dengan mengg...
# 55  Saham blue chip adalah saham perusahaan yang t...
# 56  EPS adalah singkatan dari Earning Per Share at...
# 57  Depresiasi adalah turunnya nilai suatu aset te...
# 58  Dividen properti adalah pembagian keuntungan p...
# 59  Investasi saham adalah penanaman modal jangka ...
# 60  Saham blue chip consortium adalah saham yang d...
# 61  Investasi jangka pendek biasanya berlangsung d...
# 62  Saham overvalued dapat diidentifikasi dengan m...
# 63  DER yang baik terjadi ketika nilai DER rendah,...
# 64  Saham adalah instrumen keuangan yang mewakili ...
# 65  Saham di BEI diperjualbelikan dalam satuan lot...
# 66  Lot merupakan satuan yang digunakan dalam inve...
# 67  Reksa dana memberikan keuntungan dari kenaikan...
# 68  Jika terjadi kegagalan dalam investasi saham p...
# 69  IDX80 adalah indeks saham yang terdiri dari 80...
#
#                                      Prediksi_Jawaban
# 0   Memilih saham untuk investasi jangka panjang m...
# 1   Stock split adalah pembagian saham yang ada me...
# 2   Bursa Efek Indonesia merupakan lembaga yang me...
# 3   Indikator teknis adalah alat yang digunakan da...
# 4   Dividen adalah bagian laba perusahaan pada sua...
# 5   Saham small cap adalah saham lapis tiga, yaitu...
# 6   Short selling adalah strategi di mana seorang ...
# 7   Bearish adalah istilah dalam saham yang diguna...
# 8   IDX Small-Mid Cap adalah indeks saham yang men...
# 9   Earning per Share atau EPS ialah rasio dari ne...
# 10  Laporan laba rugi perusahaan memberikan gambar...
# 11  Diversifikasi portofolio adalah strategi inves...
# 12  IDX Property adalah indeks saham yang mencakup...
# 13  Langkah - langkah cara menjual saham:\n1. Logi...
# 14  Broker adalah perantara antara pembeli dan pen...
# 15  Mengenali saham yang mengalami manipulasi pasa...
# 16  Analisis teknikal yang berkelanjutan melibatka...
# 17  Saham high beta adalah saham yang cenderung me...
# 18  IDX Agriculture adalah indeks saham yang menca...
# 19  Saham preferen adalah jenis saham yang memberi...
# 20  IDX Shariah adalah indeks saham yang mencakup ...
# 21  Karakteristik investasi bodong adalah: a. Retu...
# 22  Analisis sentimen melibatkan memantau dan meng...
# 23  IHSG atau Indeks Harga Saham Gabungan adalah i...
# 24  Analisis saham teknikal melibatkan penggunaan ...
# 25  Untuk memahami laporan keuangan perusahaan pen...
# 26  Profitability Ratio adalah rasio yang digunaka...
# 27  Pendapatan bisa diperoleh dari pekerjaan tetap...
# 28  Saham cyclical adalah saham dari perusahaan ya...
# 29  Indeks saham adalah ukuran statistik yang meng...
# 30  Kinerja manajemen perusahaan dapat diukur deng...
# 31  Analisis fundamental adalah pendekatan untuk m...
# 32  Analisis saham teknikal melibatkan penggunaan ...
# 33  EPS adalah singkatan dari Earning Per Share at...
# 34  Mengenali saham dengan potensi pertumbuhan yan...
# 35  Investor perlu mempertimbangkan berbagai fakto...
# 36  Harga saham dalam IPO ditentukan berdasarkan b...
# 37  Kebebasan finansial dapat diraih melalui dua c...
# 38  Saham blue chip mengacu pada saham perusahaan ...
# 39  Laporan Keuangan adalah catatan informasi keun...
# 40  Salah satu metode yang dapat digunakan untuk m...
# 41  Swing Trading dikenal sebagai sebuah strategi ...
# 42  Trading saham adalah transaksi jual beli surat...
# 43  Berita dan rumor dapat memiliki dampak signifi...
# 44  Analisis sektoral adalah proses menganalisis k...
# 45  Saham dividend yield adalah rasio yang menguku...
# 46  Bandar merupakan istilah gaul dalam saham yang...
# 47  IPO adalah proses di mana perusahaan pertama k...
# 48  Dividen adalah bagian laba perusahaan pada sua...
# 49  Terdapat 5 jenis opini auditor, tapi kita waji...
# 50  Trading saham adalah transaksi jual beli surat...
# 51  Analisis fundamental adalah pendekatan untuk m...
# 52  Saham dividend yield adalah rasio yang menguku...
# 53  Indeks saham digunakan sebagai indikator untuk...
# 54  Tingkat risiko saham dapat diukur dengan mengg...
# 55  Saham blue chip adalah istilah dalam saham yan...
# 56  EPS adalah singkatan dari Earning Per Share at...
# 57  Depresiasi adalah turunnya nilai suatu aset te...
# 58  Dividen properti adalah pembagian keuntungan p...
# 59  Investasi saham adalah penanaman modal jangka ...
# 60  Saham blue chip consortium adalah saham yang d...
# 61  Investasi jangka pendek biasanya berlangsung d...
# 62  Saham overvalued dapat diidentifikasi dengan m...
# 63  Debt-to-equity Ratio (DER) = Total utang berbu...
# 64  Saham adalah instrumen investasi berupa surat ...
# 65  Saham di BEI diperjualbelikan dalam satuan lot...
# 66  Lot merupakan satuan yang digunakan dalam inve...
# 67  Reksa dana memberikan keuntungan dari kenaikan...
# 68  Jika terjadi kegagalan dalam investasi saham p...
# 69  IDX80 adalah indeks saham yang terdiri dari 80...

# %%
df_testing[['Pertanyaan','Model_Sequences','Label','Label_Encoded','Predicted_Label']]
# Out:
#                                            Pertanyaan  \
# 0   Bagaimana cara memilih saham yang cocok untuk ...
# 1   Bagaimana pengaruh berita dan peristiwa ekonom...
# 2                                         Apa itu BEI
# 3   Bagaimana cara memahami dan menggunakan indika...
# 4                                    Apa itu dividen?
# 5                            Apa itu Saham small cap?
# 6                              Apa itu short selling?
# 7                                     Apa itu Bearish
# 8                          Apa itu IDX Small-Mid Cap?
# 9   Apa yang dimaksud dengan Earning per Share (EP...
# 10  Bagaimana cara membaca dan memahami laporan la...
# 11                Bagaimana diversifikasi portofolio?
# 12                              Apa itu IDX Property?
# 13                      Bagaimana cara menjual saham?
# 14                                    Apa itu broker?
# 15  Bagaimana cara mengenali saham yang mengalami ...
# 16  Apa yang dimaksud dengan analisis teknikal yan...
# 17                           Apa itu saham high beta?
# 18                           Apa itu IDX Agriculture?
# 19                            Apa itu saham preferen?
# 20                               Apa itu IDX Shariah?
# 21  Apa saja itu jenis utang berdasarkan karakteri...
# 22  Bagaimana cara menggunakan analisis sentimen d...
# 23        Apa itu IHSG (Indeks Harga Saham Gabungan)?
# 24  Apa yang dimaksud dengan analisis teknikal dal...
# 25  Bagaimana cara memahami laporan keuangan perus...
# 26                       Apa itu Profitability Ratio?
# 27  Dari mana saja pendapatan bisa diperoleh untuk...
# 28                            Apa itu saham cyclical?
# 29             Apa yang dimaksud dengan indeks saham?
# 30   Bagaimana cara mengukur kinerja investasi saham?
# 31  Apa yang dimaksud dengan analisis fundamental ...
# 32  Apa yang dimaksud dengan analisis teknikal dal...
# 33                        EPS dikatakan baik apabila?
# 34  Bagaimana cara mengenali saham dengan potensi ...
# 35  Apa yang harus dipertimbangkan oleh investor s...
# 36                         Apa itu saham IPO lock-up?
# 37                 Apa arti dari kebebasan finansial?
# 38  Bagaimana membedakan saham blue chip mid cap d...
# 39  Apa saja komponen laporan keuangan dalam inves...
# 40  Apakah ada metode strategi untuk mengidentifik...
# 41                             Apa itu Swing Trading?
# 42                             Apa itu trading saham?
# 43  Bagaimana pengaruh berita dan rumor terhadap h...
# 44        Apa yang dimaksud dengan analisis sektoral?
# 45  Apa yang dimaksud dengan saham dividend yield ...
# 46                                     Apa itu Bandar
# 47             Apa itu IPO (Initial Public Offering)?
# 48                  Apa yang dimaksud dengan dividen?
# 49  Berapa jenis opini auditor yang ada dan manaka...
# 50                 Untuk apa melakukan trading saham?
# 51  Apa yang menjadi fokus dari analisis fundament...
# 52                         DY dikatakan baik apabila?
# 53         Contoh Indeks Saham dalam investasi saham?
# 54  Bagaimana cara mengukur tingkat risiko saham d...
# 55                           Apa itu saham blue chip?
# 56                   Apa itu EPS (Earning Per Share)?
# 57                                Apa itu depresiasi?
# 58                          Apa itu Dividen Properti?
# 59                        Apa itu berinvestasi saham?
# 60                Apa itu saham blue chip consortium?
# 61  Apa perbedaan antara investasi jangka pendek d...
# 62  Bagaimana cara mengidentifikasi saham overvalu...
# 63                        DER dikatakan baik apabila?
# 64                                      Saham adalah?
# 65        Apa itu lot dalam perdagangan saham di BEI?
# 66                                       Apa itu Lot?
# 67      Apa keuntungan berinvestasi dalam reksa dana?
# 68  Apa yang harus dilakukan jika terjadi kegagala...
# 69                                     Apa itu IDX80?
#
#                      Model_Sequences      Label  Label_Encoded  \
# 0                  [16, 2, 1, 3, 33]  Investasi              1
# 1            [77, 315, 1, 306, 5, 2]   Strategi              3
# 2                              [290]    Istilah              2
# 3                [32, 103, 22, 9, 2]    Trading              4
# 4                               [15]    Istilah              2
# 5                        [2, 1, 243]    Istilah              2
# 6                         [129, 130]    Istilah              2
# 7                                [1]    Istilah              2
# 8                    [11, 1, 1, 243]    Istilah              2
# 9               [270, 229, 1, 12, 2]    Istilah              2
# 10          [106, 32, 19, 40, 1, 13]   Strategi              3
# 11                        [134, 135]   Strategi              3
# 12                           [11, 1]    Istilah              2
# 13                           [61, 2]   Strategi              3
# 14                             [264]    Istilah              2
# 15                [43, 2, 66, 1, 10]   Strategi              3
# 16                  [4, 22, 1, 9, 2]    Trading              4
# 17                       [2, 265, 1]    Istilah              2
# 18                           [11, 1]    Istilah              2
# 19                           [2, 69]    Istilah              2
# 20                           [11, 1]    Istilah              2
# 21                [39, 63, 105, 145]    Istilah              2
# 22                    [4, 286, 3, 2]  Investasi              1
# 23                [284, 53, 5, 2, 1]    Istilah              2
# 24                     [4, 22, 3, 2]  Investasi              1
# 25                  [32, 19, 21, 13]   Strategi              3
# 26                            [1, 7]    Istilah              2
# 27              [1, 1, 101, 102, 44]   Strategi              3
# 28                            [2, 1]    Istilah              2
# 29                           [53, 2]    Istilah              2
# 30                   [25, 107, 3, 2]  Investasi              1
# 31                     [4, 28, 3, 2]  Investasi              1
# 32                     [4, 22, 3, 2]  Investasi              1
# 33                               [1]  Investasi              1
# 34             [43, 2, 56, 93, 3, 2]  Investasi              1
# 35                [90, 55, 23, 2, 8]        IPO              0
# 36                    [2, 8, 1, 316]    Istilah              2
# 37                      [1, 102, 44]    Istilah              2
# 38  [114, 2, 14, 17, 1, 243, 1, 243]    Istilah              2
# 39                   [84, 19, 21, 3]  Investasi              1
# 40         [1, 108, 26, 2, 61, 5, 1]   Strategi              3
# 41                            [1, 9]    Istilah              2
# 42                            [9, 2]    Istilah              2
# 43          [77, 315, 1, 5, 2, 3, 2]  Investasi              1
# 44                            [4, 1]    Istilah              2
# 45                 [2, 24, 125, 210]    Istilah              2
# 46                               [1]    Istilah              2
# 47                   [8, 50, 29, 38]    Istilah              2
# 48                              [15]    Istilah              2
# 49         [39, 1, 269, 1, 1, 90, 3]  Investasi              1
# 50                            [9, 2]    Trading              4
# 51                  [1, 4, 28, 3, 2]  Investasi              1
# 52                             [210]  Investasi              1
# 53                  [1, 53, 2, 3, 2]  Investasi              1
# 54               [25, 1, 6, 2, 3, 2]  Investasi              1
# 55                       [2, 14, 17]    Istilah              2
# 56                     [1, 270, 229]    Istilah              2
# 57                               [1]    Istilah              2
# 58                           [15, 1]    Istilah              2
# 59                            [3, 2]    Istilah              2
# 60                    [2, 14, 17, 1]    Istilah              2
# 61               [114, 3, 33, 1, 33]  Investasi              1
# 62                     [26, 2, 1, 1]   Strategi              3
# 63                             [144]  Investasi              1
# 64                               [2]    Istilah              2
# 65                   [1, 81, 2, 290]    Istilah              2
# 66                               [1]    Istilah              2
# 67                 [100, 3, 112, 62]  Investasi              1
# 68                         [1, 3, 2]  Investasi              1
# 69                               [1]    Istilah              2
#
#     Predicted_Label
# 0                 1
# 1                 2
# 2                 2
# 3                 4
# 4                 2
# 5                 2
# 6                 2
# 7                 2
# 8                 2
# 9                 2
# 10                3
# 11                2
# 12                2
# 13                3
# 14                2
# 15                3
# 16                4
# 17                2
# 18                2
# 19                2
# 20                2
# 21                3
# 22                1
# 23                2
# 24                2
# 25                3
# 26                2
# 27                3
# 28                2
# 29                2
# 30                3
# 31                2
# 32                2
# 33                2
# 34                1
# 35                0
# 36                0
# 37                3
# 38                2
# 39                2
# 40                3
# 41                2
# 42                2
# 43                1
# 44                2
# 45                2
# 46                2
# 47                0
# 48                2
# 49                1
# 50                2
# 51                2
# 52                2
# 53                2
# 54                1
# 55                2
# 56                2
# 57                2
# 58                2
# 59                2
# 60                2
# 61                1
# 62                3
# 63                2
# 64                2
# 65                2
# 66                2
# 67                1
# 68                1
# 69                2

# %%
le = pickle.load(open('LE.pkl', 'rb'))
df_testing['Predicted_Label'] = le.inverse_transform(df_testing['Predicted_Label'])
excel = df_testing[['Pertanyaan','stemmed','Model_Sequences','Predicted_Label','Label','Corpus_Sequences']]
excel.to_excel("pengujian_model.xlsx")

# %%
# Convert .ipynb ke .py untuk digunakan pada tahap re-training pertanyaan OOV yang baru ditambahkan
# !jupyter nbconvert --to script main_notebook.ipynb
